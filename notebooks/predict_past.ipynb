# %%
import pandas as pd

# %%
df = pd.read_csv("../nba_games.csv", index_col=0)

# %%
#Print all columns in df without 
df.columns
# Out:
# Index(['mp', 'mp.1', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta',
#        ...
#        'tov%_max_opp', 'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp',
#        'team_opp', 'total_opp', 'home_opp', 'season', 'date', 'won'],
#       dtype='object', length=150)

# %%
df = df.sort_values("date")

# %%
df
# Out:
#           mp   mp.1    fg   fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 16086  240.0  240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  ...
# 16904  240.0  240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  ...
# 16905  240.0  240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  ...
# 16087  240.0  240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  ...
# 1225   240.0  240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  ...
# ...      ...    ...   ...   ...    ...   ...   ...    ...   ...   ...  ...
# 973    240.0  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  ...
# 11533  240.0  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  ...
# 11532  240.0  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  ...
# 7477   240.0  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  ...
# 7476   240.0  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  ...
#
#        tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 16086          69.4          43.7         206.0         104.0       GSW
# 16904          53.2          34.6         162.0         104.0       CHI
# 16905          30.4          29.0         138.0         105.0       CLE
# 16087          37.5          38.9         201.0         120.0       NOP
# 1225           33.3          23.6         132.0         104.0       DET
# ...             ...           ...           ...           ...       ...
# 973            42.9          36.3         133.0         112.0       GSW
# 11533          45.0          94.4         300.0         112.0       BOS
# 11532          33.3          36.2         222.0         107.0       GSW
# 7477           33.3          31.5         186.0         111.0       GSW
# 7476          100.0          42.6         141.0         126.0       BOS
#
#        total_opp  home_opp  season        date    won
# 16086        111         1    2016  2015-10-27  False
# 16904         97         1    2016  2015-10-27  False
# 16905         95         0    2016  2015-10-27   True
# 16087         95         0    2016  2015-10-27   True
# 1225         106         0    2016  2015-10-27  False
# ...          ...       ...     ...         ...    ...
# 973          107         0    2022  2022-06-10  False
# 11533         94         0    2022  2022-06-13   True
# 11532        104         1    2022  2022-06-13  False
# 7477         103         0    2022  2022-06-16  False
# 7476          90         1    2022  2022-06-16   True
#
# [17772 rows x 150 columns]

# %%
df = df.reset_index(drop=True)

# %%
del df["mp.1"]
del df["mp_opp.1"]
del df["index_opp"]

# %% [markdown]
# Want to predict how the team did in the next game. So pull the won column from the next game and move it back one row.

# %%
def add_target(team):
    team["target"] = team["won"].shift(-1)
    return team

df = df.groupby("team", group_keys=False).apply(add_target)
# Out:
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1127067056.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("team", group_keys=False).apply(add_target)

# %%
df[df["team"] == "WAS"]
# Out:
#           mp    fg    fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 11     240.0  33.0   84.0  0.393   7.0  28.0  0.250  15.0  25.0  0.600  ...
# 63     240.0  35.0   68.0  0.515  12.0  21.0  0.571  36.0  44.0  0.818  ...
# 69     240.0  38.0   90.0  0.422   6.0  22.0  0.273  28.0  33.0  0.848  ...
# 124    240.0  42.0   87.0  0.483   8.0  23.0  0.348  10.0  14.0  0.714  ...
# 161    240.0  36.0   88.0  0.409   8.0  25.0  0.320  18.0  23.0  0.783  ...
# ...      ...   ...    ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17471  240.0  38.0   82.0  0.463   8.0  21.0  0.381  18.0  20.0  0.900  ...
# 17483  240.0  56.0  101.0  0.554  13.0  30.0  0.433   7.0  14.0  0.500  ...
# 17510  240.0  42.0   86.0  0.488  10.0  35.0  0.286   9.0  11.0  0.818  ...
# 17538  240.0  35.0   69.0  0.507   9.0  28.0  0.321  13.0  17.0  0.765  ...
# 17558  240.0  42.0   94.0  0.447   8.0  23.0  0.348  16.0  26.0  0.615  ...
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 11             25.2         134.0          98.0       ORL         87
# 63             32.4         138.0         122.0       MIL        113
# 69             28.7         153.0         108.0       NYK        117
# 124            30.0         160.0         109.0       SAS         99
# 161            41.6         146.0         103.0       BOS        118
# ...             ...           ...           ...       ...        ...
# 17471          34.4         245.0         116.0       BOS        144
# 17483          32.8         168.0         132.0       MIN        114
# 17510          60.2         159.0         114.0       ATL        118
# 17538          35.5         135.0         104.0       NYK        114
# 17558          37.3         161.0         118.0       CHO        124
#
#        home_opp  season        date    won  target
# 11            1    2016  2015-10-28   True    True
# 63            1    2016  2015-10-30   True   False
# 69            0    2016  2015-10-31  False    True
# 124           0    2016  2015-11-04   True   False
# 161           1    2016  2015-11-06  False   False
# ...         ...     ...         ...    ...     ...
# 17471         1    2022  2022-04-03  False    True
# 17483         1    2022  2022-04-05   True   False
# 17510         1    2022  2022-04-06  False   False
# 17538         0    2022  2022-04-08  False   False
# 17558         1    2022  2022-04-10  False     NaN
#
# [580 rows x 148 columns]

# %% [markdown]
# For all the null values in the target column, meaning there is no next game, set those to 2

# %%
df["target"][pd.isnull(df["target"])] = 2
# Out:
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1618397414.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["target"][pd.isnull(df["target"])] = 2
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_65111/1618397414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["target"][pd.isnull(df["target"])] = 2

# %% [markdown]
# Turn True to 1 False to 0 and Null to 2

# %%
df["target"] = df["target"].astype(int, errors="ignore")

# %%
df["target"].value_counts()
# Out:
# target
# 1    8872
# 0    8870
# 2      30
# Name: count, dtype: int64

# %%
nulls = pd.isnull(df).sum()
nulls = nulls[nulls > 0]

# %% [markdown]
# Delete columns with nulls

# %%
valid_columns = df.columns[~df.columns.isin(nulls.index)]

# %%
df = df[valid_columns].copy()

# %% [markdown]
# For most machine learning algorithms need a smaller number of columns. Use a feature selector to do this. Time series split useful to use old data to predict newer data.

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import RidgeClassifier

rr = RidgeClassifier(alpha=1)
split = TimeSeriesSplit(n_splits=3)

sfs = SequentialFeatureSelector(rr, n_features_to_select=30, direction="forward", cv=split, n_jobs=1)

# %% [markdown]
# Scale the columns. Ridge regression works best when columns are scaled. We are going to scale each column between 0 and 1. Cant scale certain columns.

# %%
removed_columns = ["season", "date", "won", "target", "team", "team_opp"]
selected_columns = df.columns[~df.columns.isin(removed_columns)]

# %%
print(selected_columns)
# Out:
# Index(['mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta', 'ft%',
#        ...
#        'trb%_max_opp', 'ast%_max_opp', 'stl%_max_opp', 'blk%_max_opp',
#        'tov%_max_opp', 'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp',
#        'total_opp', 'home_opp'],
#       dtype='object', length=142)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[selected_columns] = scaler.fit_transform(df[selected_columns])

# %%
sfs.fit(df[selected_columns], df["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30, n_jobs=1)

# %% [markdown]
# If the feature select has picked the feature .get_support will be true. So we want to find the columns the selector picked

# %%
predictors = list(selected_columns[sfs.get_support()])

# %% [markdown]
# Split up data by season and use past season to predict future seasons. Need 2 seasons of data to make predictons about future season

# %%
def backtest(data, model, predictors, start=2, step=1):
    # list of dataframes where each df is predictions for a season
    all_predictions = []

    seasons = sorted(data["season"].unique())

    for i in range(start, len(seasons), step):
        season = seasons[i]

        # Taining data is all data from previous seasons
        train = data[data["season"] < season]

        # Testing data is all data from the current season
        test = data[data["season"] == season]

        # Fit the model to the training data
        model.fit(train[predictors], train["target"])

        # Make predictions on the testing data
        preds = model.predict(test[predictors])

        # Make the predictions a pandas series with the same index as the testing data
        preds = pd.Series(preds, index=test.index)

        # combine the actual and predicted values
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]

        # Add the combined data to the list of all predictions
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(df, rr, predictors)

# %%
from sklearn.metrics import accuracy_score

predictions = predictions[predictions["actual"] != 2]
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.5485110470701249

# %%
df.groupby(["home"]).apply(lambda x: x[x["won"] == 1].shape[0] / x.shape[0])
# Out:
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/330557953.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby(["home"]).apply(lambda x: x[x["won"] == 1].shape[0] / x.shape[0])
# home
# 0.0    0.428314
# 1.0    0.571686
# dtype: float64

# %% [markdown]
# Currently only using the last game to predict the next game. Its a better idea to use an average of the last 10 games to make the prediction.

# %%
import warnings

df_rolling = df[list(selected_columns) + ["won", "team", "season"]]

def find_team_averages(team):
    # Identify non-numeric (object) columns
    non_numeric = team.select_dtypes(exclude='number').columns
    
    if len(non_numeric) > 0:
        # Mimic the old behavior's warning
        warnings.warn(
            "Dropping of nuisance columns in rolling operations is deprecated; "
            "in a future version this will raise TypeError. "
            f"Select only valid columns before calling the operation. "
            f"Dropped columns were {list(non_numeric)}",
            FutureWarning
        )
    
    # Drop non-numeric columns to avoid errors
    numeric_cols = team.drop(columns=non_numeric, errors='ignore')
    
    # Now apply rolling mean to numeric columns only
    rolling = numeric_cols.rolling(10).mean()
    return rolling

df_rolling = df_rolling.groupby(["team", "season"], group_keys=False).apply(find_team_averages)
# Out:
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# ...
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:11: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were ['won', 'team']
#   warnings.warn(
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/2052060719.py:26: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_rolling = df_rolling.groupby(["team", "season"], group_keys=False).apply(find_team_averages)

# %%
df_rolling
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.381818  0.292647  0.428230  0.468966  0.477273  0.448100
# 17768  0.0  0.502273  0.364706  0.517703  0.455172  0.481818  0.440736
# 17769  0.0  0.354545  0.279412  0.404545  0.437931  0.465152  0.429572
# 17770  0.0  0.354545  0.294118  0.389952  0.434483  0.459091  0.431710
# 17771  0.0  0.484091  0.379412  0.482297  0.486207  0.507576  0.448812
#
#              ft       fta       ft%  ...  ast%_max_opp  stl%_max_opp  \
# 0           NaN       NaN       NaN  ...           NaN           NaN
# 1           NaN       NaN       NaN  ...           NaN           NaN
# 2           NaN       NaN       NaN  ...           NaN           NaN
# 3           NaN       NaN       NaN  ...           NaN           NaN
# 4           NaN       NaN       NaN  ...           NaN           NaN
# ...         ...       ...       ...  ...           ...           ...
# 17767  0.434884  0.373016  0.764177  ...      0.373394        0.0570
# 17768  0.320930  0.282540  0.757993  ...      0.546101        0.0716
# 17769  0.434884  0.385714  0.736639  ...      0.384060        0.0591
# 17770  0.406977  0.357143  0.754142  ...      0.393693        0.0572
# 17771  0.316279  0.269841  0.801750  ...      0.475803        0.0656
#
#        blk%_max_opp  tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  \
# 0               NaN           NaN           NaN           NaN           NaN
# 1               NaN           NaN           NaN           NaN           NaN
# 2               NaN           NaN           NaN           NaN           NaN
# 3               NaN           NaN           NaN           NaN           NaN
# 4               NaN           NaN           NaN           NaN           NaN
# ...             ...           ...           ...           ...           ...
# 17767        0.1113      0.471908      0.170603      0.431754      0.522353
# 17768        0.1171      0.374109      0.321566      0.642654      0.564706
# 17769        0.1113      0.483229      0.174711      0.438863      0.483529
# 17770        0.1111      0.483229      0.172144      0.460190      0.472941
# 17771        0.1152      0.444025      0.308601      0.628910      0.568235
#
#        total_opp  home_opp  season
# 0            NaN       NaN     NaN
# 1            NaN       NaN     NaN
# 2            NaN       NaN     NaN
# 3            NaN       NaN     NaN
# 4            NaN       NaN     NaN
# ...          ...       ...     ...
# 17767   0.348077       0.5  2022.0
# 17768   0.392308       0.4  2022.0
# 17769   0.350000       0.5  2022.0
# 17770   0.344231       0.5  2022.0
# 17771   0.395192       0.5  2022.0
#
# [17772 rows x 137 columns]

# %%
rolling_cols = [f"{col}_10" for col in df_rolling.columns]

df_rolling.columns = rolling_cols

df = pd.concat([df, df_rolling], axis=1)

# %%
df = df.dropna()

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 243    0.0  0.522727  0.382353  0.523923  0.344828  0.333333  0.457245
# 251    0.0  0.659091  0.426471  0.645933  0.620690  0.515152  0.562945
# 252    0.0  0.386364  0.382353  0.358852  0.206897  0.181818  0.445368
# 253    0.0  0.500000  0.382353  0.497608  0.344828  0.318182  0.475059
# 256    0.0  0.318182  0.132353  0.500000  0.275862  0.272727  0.432304
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17768  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17769  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17770  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17771  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  ast%_max_opp_10  stl%_max_opp_10  \
# 243    0.255814  0.238095  0.708285  ...         0.311927           0.0628
# 251    0.325581  0.238095  0.927655  ...         0.412271           0.0613
# 252    0.511628  0.412698  0.827305  ...         0.245757           0.0625
# 253    0.325581  0.349206  0.593932  ...         0.283257           0.0646
# 256    0.581395  0.444444  0.879813  ...         0.307569           0.0741
# ...         ...       ...       ...  ...              ...              ...
# 17767  0.302326  0.285714  0.693116  ...         0.373394           0.0570
# 17768  0.279070  0.222222  0.844807  ...         0.546101           0.0716
# 17769  0.465116  0.476190  0.623104  ...         0.384060           0.0591
# 17770  0.232558  0.174603  0.903151  ...         0.393693           0.0572
# 17771  0.162791  0.111111  1.000000  ...         0.475803           0.0656
#
#        blk%_max_opp_10  tov%_max_opp_10  usg%_max_opp_10  ortg_max_opp_10  \
# 243             0.0679         0.413522         0.124134         0.361611
# 251             0.0772         0.469497         0.219641         0.394787
# 252             0.1145         0.437841         0.138126         0.507109
# 253             0.0759         0.512159         0.133633         0.277251
# 256             0.0982         0.313312         0.179974         0.500000
# ...                ...              ...              ...              ...
# 17767           0.1113         0.471908         0.170603         0.431754
# 17768           0.1171         0.374109         0.321566         0.642654
# 17769           0.1113         0.483229         0.174711         0.438863
# 17770           0.1111         0.483229         0.172144         0.460190
# 17771           0.1152         0.444025         0.308601         0.628910
#
#        drtg_max_opp_10  total_opp_10  home_opp_10  season_10
# 243           0.449412      0.347115          0.4     2016.0
# 251           0.531765      0.324038          0.5     2016.0
# 252           0.360000      0.351923          0.6     2016.0
# 253           0.388235      0.308654          0.4     2016.0
# 256           0.471765      0.380769          0.5     2016.0
# ...                ...           ...          ...        ...
# 17767         0.522353      0.348077          0.5     2022.0
# 17768         0.564706      0.392308          0.4     2022.0
# 17769         0.483529      0.350000          0.5     2022.0
# 17770         0.472941      0.344231          0.5     2022.0
# 17771         0.568235      0.395192          0.5     2022.0
#
# [15882 rows x 279 columns]

# %%
def shift_col(team, col_name):
    next_col = team[col_name].shift(-1)
    return next_col

def add_col(df, col_name):
    return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))

df["home_next"] = add_col(df, "home")
df["team_opp_next"] = add_col(df, "team_opp")
df["date_next"] = add_col(df, "date")
# Out:
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/1688004556.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/1688004556.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))
# /var/folders/6v/tkqp5lhn4l90pnrnv57z_cnw0000gn/T/ipykernel_37385/1688004556.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))

# %%
df = df.copy()

# %%
full = df.merge(df[rolling_cols + ["team_opp_next", "date_next", "team"]], 
left_on=["team", "date_next"], 
right_on=["team_opp_next", "date_next"])

# %%
full[["team_x", "team_opp_next_x", "team_y", "team_opp_next_y", "date_next"]]
# Out:
#       team_x team_opp_next_x team_y team_opp_next_y   date_next
# 0        SAC             TOR    TOR             SAC  2015-11-15
# 1        TOR             SAC    SAC             TOR  2015-11-15
# 2        CLE             DET    DET             CLE  2015-11-17
# 3        GSW             TOR    TOR             GSW  2015-11-17
# 4        DEN             NOP    NOP             DEN  2015-11-17
# ...      ...             ...    ...             ...         ...
# 15769    BOS             GSW    GSW             BOS  2022-06-10
# 15770    GSW             BOS    BOS             GSW  2022-06-13
# 15771    BOS             GSW    GSW             BOS  2022-06-13
# 15772    GSW             BOS    BOS             GSW  2022-06-16
# 15773    BOS             GSW    GSW             BOS  2022-06-16
#
# [15774 rows x 5 columns]

# %%
removed_columns = list(full.columns[full.dtypes == "object"]) + removed_columns

# %%
full.columns[full.dtypes == "object"]
# Out:
# Index(['team_x', 'team_opp', 'date', 'team_opp_next_x', 'date_next',
#        'team_opp_next_y', 'team_y'],
#       dtype='object')

# %%
removed_columns
# Out:
# ['team_x',
#  'team_opp',
#  'date',
#  'team_opp_next_x',
#  'date_next',
#  'team_opp_next_y',
#  'team_y',
#  'season',
#  'date',
#  'won',
#  'target',
#  'team',
#  'team_opp']

# %%
selected_columns = full.columns[~full.columns.isin(removed_columns)]

# %%
print("Selected columns:", selected_columns)
print("Removed columns:", removed_columns)
# Out:
# Selected columns: Index(['mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta', 'ft%',
#        ...
#        'ast%_max_opp_10_y', 'stl%_max_opp_10_y', 'blk%_max_opp_10_y',
#        'tov%_max_opp_10_y', 'usg%_max_opp_10_y', 'ortg_max_opp_10_y',
#        'drtg_max_opp_10_y', 'total_opp_10_y', 'home_opp_10_y', 'season_10_y'],
#       dtype='object', length=411)
# Removed columns: ['team_x', 'team_opp', 'date', 'team_opp_next_x', 'date_next', 'team_opp_next_y', 'team_y', 'season', 'date', 'won', 'target', 'team', 'team_opp']

# %%
selected_columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 selected_columns
#
# NameError: name 'selected_columns' is not defined

# %%
sfs.fit(full[selected_columns], full["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30, n_jobs=1)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictions = backtest(full, rr, predictors)

# %%
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.6316121474272326

# %%
from nba_api.live.nba.endpoints import scoreboard
games = scoreboard.ScoreBoard()
games_data = games.get_dict()  # Returns data as a dictionary

# %%
games_data
# Out:
# {'meta': {'version': 1,
#   'request': 'https://nba-prod-us-east-1-mediaops-stats.s3.amazonaws.com/NBA/liveData/scoreboard/todaysScoreboard_00.json',
#   'time': '2024-12-12 06:33:12.3312',
#   'code': 200},
#  'scoreboard': {'gameDate': '2024-12-12',
#   'leagueId': '00',
#   'leagueName': 'National Basketball Association',
#   'games': [{'gameId': '0022401205',
#     'gameCode': '20241212/DETBOS',
#     'gameStatus': 1,
#     'gameStatusText': '7:30 pm ET',
#     'period': 0,
#     'gameClock': '',
#     'gameTimeUTC': '2024-12-13T00:30:00Z',
#     'gameEt': '2024-12-12T19:30:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'gameLabel': '',
#     'gameSubLabel': '',
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'gameSubtype': '',
#     'homeTeam': {'teamId': 1610612738,
#      'teamName': 'Celtics',
#      'teamCity': 'Boston',
#      'teamTricode': 'BOS',
#      'wins': 19,
#      'losses': 5,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'awayTeam': {'teamId': 1610612765,
#      'teamName': 'Pistons',
#      'teamCity': 'Detroit',
#      'teamTricode': 'DET',
#      'wins': 10,
#      'losses': 15,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'gameLeaders': {'homeLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'BOS',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0},
#      'awayLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'DET',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022401206',
#     'gameCode': '20241212/TORMIA',
#     'gameStatus': 1,
#     'gameStatusText': '7:30 pm ET',
#     'period': 0,
#     'gameClock': '',
#     'gameTimeUTC': '2024-12-13T00:30:00Z',
#     'gameEt': '2024-12-12T19:30:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'gameLabel': '',
#     'gameSubLabel': '',
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'gameSubtype': '',
#     'homeTeam': {'teamId': 1610612748,
#      'teamName': 'Heat',
#      'teamCity': 'Miami',
#      'teamTricode': 'MIA',
#      'wins': 12,
#      'losses': 10,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'awayTeam': {'teamId': 1610612761,
#      'teamName': 'Raptors',
#      'teamCity': 'Toronto',
#      'teamTricode': 'TOR',
#      'wins': 7,
#      'losses': 18,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'gameLeaders': {'homeLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'MIA',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0},
#      'awayLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'TOR',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022401207',
#     'gameCode': '20241212/SACNOP',
#     'gameStatus': 1,
#     'gameStatusText': '8:00 pm ET',
#     'period': 0,
#     'gameClock': '',
#     'gameTimeUTC': '2024-12-13T01:00:00Z',
#     'gameEt': '2024-12-12T20:00:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'gameLabel': '',
#     'gameSubLabel': '',
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'gameSubtype': '',
#     'homeTeam': {'teamId': 1610612740,
#      'teamName': 'Pelicans',
#      'teamCity': 'New Orleans',
#      'teamTricode': 'NOP',
#      'wins': 5,
#      'losses': 20,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'awayTeam': {'teamId': 1610612758,
#      'teamName': 'Kings',
#      'teamCity': 'Sacramento',
#      'teamTricode': 'SAC',
#      'wins': 12,
#      'losses': 13,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'gameLeaders': {'homeLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'NOP',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0},
#      'awayLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'SAC',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}}]}}
